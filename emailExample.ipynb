# %%
import pandas as pd
import bireader
from bireader.biread_emailtxt import biread_email

# %%
file_path="data/raw-email.txt"

# %%
df = biread_email(file_path)
df
# Out:
#          Delivered-To                                           Received  \
# 0  redacted@gmail.com  by 2002:a05:6802:28a9:b0:5e0:75a1:9c15 with SM...
#
#                                 X-Google-Smtp-Source  \
# 0  AGHT+IGAfnP8tGH7zcciPVYCC314wrGkqMaiRoYhsPaRkJ...
#
#                                           X-Received  \
# 0  by 2002:a17:903:187:b0:235:ec11:f0ee with SMTP...
#
#                                             ARC-Seal  \
# 0  i=1; a=rsa-sha256; t=1756311673; cv=none;     ...
#
#                                ARC-Message-Signature  \
# 0  i=1; a=rsa-sha256; c=relaxed/relaxed; d=google...
#
#                           ARC-Authentication-Results  \
# 0  i=1; mx.google.com;       dkim=pass header.i=@...
#
#                                       Return-Path  \
# 0  <bounce-3146-8321-p005ebp-F-F-F-F-F@txm33.net>
#
#                                         Received-SPF  \
# 0  pass (google.com: domain of bounce-3146-8321-p...
#
# ...

# %%
df
# Out:
#          Delivered-To                                           Received  \
# 0  redacted@gmail.com  by 2002:a05:6802:28a9:b0:5e0:75a1:9c15 with SM...
#
#                                 X-Google-Smtp-Source  \
# 0  AGHT+IGAfnP8tGH7zcciPVYCC314wrGkqMaiRoYhsPaRkJ...
#
#                                           X-Received  \
# 0  by 2002:a17:903:187:b0:235:ec11:f0ee with SMTP...
#
#                                             ARC-Seal  \
# 0  i=1; a=rsa-sha256; t=1756311673; cv=none;     ...
#
#                                ARC-Message-Signature  \
# 0  i=1; a=rsa-sha256; c=relaxed/relaxed; d=google...
#
#                           ARC-Authentication-Results  \
# 0  i=1; mx.google.com;       dkim=pass header.i=@...
#
#                                       Return-Path  \
# 0  <bounce-3146-8321-p005ebp-F-F-F-F-F@txm33.net>
#
#                                         Received-SPF  \
# 0  pass (google.com: domain of bounce-3146-8321-p...
#
# ...
